# %% [markdown]
# ## K8sGPT
#
# Installieren Sie den K8sGPT-Operator mit Helm:

# %%
# %%bash
# wget -S https://github.com/k8sgpt-ai/k8sgpt/releases/latest/download/k8sgpt_Linux_x86_64.tar.gz
# tar -xzf k8sgpt_Linux_x86_64.tar.gz
# sudo mv k8sgpt /usr/local/bin/

# %%
# %%bash
# k8sgpt

# %% [markdown]
# ---
#
# ### K8s Operator installieren

# %%
# %%bash
# helm repo add k8sgpt https://charts.k8sgpt.ai
# helm repo update
# helm upgrade --install k8sgpt-operator k8sgpt/k8sgpt-operator \
#   -n k8sgpt-operator-system \
#   --create-namespace \
#   --set serviceMonitor.enabled=true \
#   --set serviceMonitor.namespace=opentelemetry \
#   --set grafanaDashboard.enabled=true \
#   --set grafanaDashboard.namespace=opentelemetry

# %% [markdown]
# Erstellen Sie eine K8sGPT-Konfiguration mit Ihren KI-Anbietereinstellungen:

# %%
# %%bash
# kubectl apply -f - <<EOF
# apiVersion: core.k8sgpt.ai/v1alpha1
# kind: K8sGPT
# metadata:
#   name: k8sgpt
#   namespace: k8sgpt-operator-system
# spec:
#   ai:
#     enabled: false
#     backend: openai
#     model: gpt-4o-mini
#   targetNamespace: yaml
#   analysis:
#     interval: 1m
#   noCache: false
#   version: v0.4.32
# EOF

# %% [markdown]
# ---
#
# ## Fehlerhaften Pod/Services starten

# %%
# %%bash
# kubectl create namespace yaml
# cat <<%EOF% | kubectl apply -f -
# apiVersion: v1
# kind: Pod
# metadata:
#   labels:
#     app.kubernetes.io/name: webshop
#   name: webshop
#   namespace: yaml
# spec:
#   containers:
#   - image: registry.gitlab.com/ch-mc-b/autoshop/shop:2.0.0
#     name: webshop
# %EOF%
# cat <<%EOF% | kubectl apply -f -
# apiVersion: v1
# kind: Service
# metadata:
#   labels:
#     app.kubernetes.io/name: webshop
#   name: webshop
#   namespace: yaml
# spec:
#   ports:
#   - port: 8080
#     protocol: TCP
#     targetPort: 8080
#   selector:
#     app.kubernetes.io/name: webshop2
#   type: LoadBalancer
# %EOF%

# %%
# %%bash
# k8sgpt analyze -n yaml

# %%
# %%bash
# source ~/data/env.py
# cat ~/data/env.py
# k8sgpt auth add --backend openai --model gpt-4o --password ${OPENAI_API_KEY}

# %%
# %%bash
# k8sgpt analyze -n yaml -l german --explain

# %%
# %%bash
# kubectl get results -A
# kubectl describe -n k8sgpt-operator-system result/yamlwebshop

# %% [markdown]
# ---
#
# ### Fehlerkorrektur

# %% [markdown]
# ---
#
# ## Dashboard (Grafana) und Metricen scrappen

# %%
# %%bash
# PROM_SA=$(kubectl get prometheus -n opentelemetry -o jsonpath='{.items[0].spec.serviceAccountName}')
# [ -n "$PROM_SA" ] || PROM_SA=prometheus-k8s
#
# kubectl apply -f - <<EOF
# apiVersion: rbac.authorization.k8s.io/v1
# kind: ClusterRole
# metadata:
#   name: k8sgpt-operator-metrics-reader
# rules:
#   - nonResourceURLs:
#       - /metrics
#     verbs:
#       - get
# EOF
#
# kubectl apply -f - <<EOF
# apiVersion: rbac.authorization.k8s.io/v1
# kind: ClusterRoleBinding
# metadata:
#   name: k8sgpt-operator-metrics-reader-prometheus
# roleRef:
#   apiGroup: rbac.authorization.k8s.io
#   kind: ClusterRole
#   name: k8sgpt-operator-metrics-reader
# subjects:
#   - kind: ServiceAccount
#     name: ${PROM_SA}
#     namespace: opentelemetry
# EOF

# %%
# %%bash
# K8SGPT_NS="k8sgpt-operator-system"
# SVC="k8sgpt-operator-controller-manager-metrics-service"
#
# SM_LINE="$(kubectl get servicemonitor -A --no-headers | grep -i k8sgpt | head -n1 || true)"
#
# if [ -z "$SM_LINE" ]; then
#   echo "Kein k8sgpt ServiceMonitor gefunden."
#   echo "Dann kann Prometheus k8sgpt nicht automatisch scrapen."
#   kubectl get servicemonitor -A
#   exit 1
# fi
#
# SM_NS="$(echo "$SM_LINE" | awk '{print $1}')"
# SM_NAME="$(echo "$SM_LINE" | awk '{print $2}')"
#
# echo "ServiceMonitor: $SM_NS/$SM_NAME"
# echo "Metrics-Service: $K8SGPT_NS/$SVC"
#
# echo
# echo "Selector vom ServiceMonitor:"
# kubectl get servicemonitor -n "$SM_NS" "$SM_NAME" \
#   -o jsonpath='{.spec.selector.matchLabels}{"\n"}'
#
# echo
# echo "Labels auf Metrics-Service setzen:"
# for kv in $(kubectl get servicemonitor -n "$SM_NS" "$SM_NAME" \
#   -o go-template='{{range $k,$v := .spec.selector.matchLabels}}{{printf "%s=%s\n" $k $v}}{{end}}'); do
#   echo "kubectl label svc -n $K8SGPT_NS $SVC $kv --overwrite"
#   kubectl label svc -n "$K8SGPT_NS" "$SVC" "$kv" --overwrite
# done
#
# echo
# echo "Kontrolle:"
# kubectl get svc -n "$K8SGPT_NS" "$SVC" --show-labels
# kubectl get endpoints -n "$K8SGPT_NS" "$SVC" -o wide
# kubectl get servicemonitor -n "$SM_NS" "$SM_NAME" -o wide

# %%
# %%bash
# NAMESPACE="opentelemetry"
# SERVER_IP="$(cat ~/data/server-ip 2>/dev/null || true)"
# PROMETHEUS_PORT="$(kubectl -n "${NAMESPACE}" get svc prometheus-prometheus -o=jsonpath='{.spec.ports[?(@.port==9090)].nodePort}')"
# GRAFANA_PORT="$(kubectl -n "${NAMESPACE}" get svc prometheus-grafana -o=jsonpath='{.spec.ports[?(@.port==80)].nodePort}')"
#
# echo "Grafana UI      : http://${SERVER_IP}:${GRAFANA_PORT}"
# echo "Prometheus UI   : http://${SERVER_IP}:${PROMETHEUS_PORT}"

# %% [markdown]
# ---
#
# ### Aufräumen

# %%
# %%bash
# helm uninstall -n k8sgpt-operator-system k8sgpt-operator
# kubectl delete ns yaml --wait=false
# kubectl delete ns k8sgpt-operator-system --wait=false
