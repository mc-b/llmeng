# %% [markdown]
# ## LLM Capability (Fähigkeiten)
#
# Damit wir nicht zuerst zusätzliche Software installieren müssen, ist die KI-Umgebung **Ollama** bereits vorbereitet.
#
# Darin stehen zwei lokale Large Language Models zur Verfügung.

# %%
# %%bash
# ollama list || true

# %% [markdown]
# Falls keine Verbindung zum Ollama Server hergestellt werden kann, diesen neu starten

# %%
# %%bash
# sudo systemctl restart ollama
# ollama list

# %% [markdown]
# Bevor wir starten, müssen wir noch einige Umgebungsvariablen setzen. Damit legen wir fest, welche KI-Umgebung verwendet wird und mit welchem LLM gearbeitet werden soll.

# %%
# %%bash
# source ~/data/env.py
# cat <<EOF | tee ~/data/env.py
# OPENAI_API_KEY="$OPENAI_API_KEY"
# HF_TOKEN=""
# AI_KUBECONFIG="$AI_KUBECONFIG"
# AI_MODEL="llama3.1:8b-instruct-q4_K_M"
# AI_NAME=""
# AI_IP="${AI_IP}"
# AI_BASE_URL='http://localhost:11434/v1'
# EOF

# %% [markdown]
# Über die Jupyter-Notebook-Erweiterung `%%ai` können wir direkt mit diesen Modellen kommunizieren.
#
# Dazu senden wir eine Anfrage an das Allround-Sprachmodell `llama3.1:8b-instruct-q4_K_M`. Das Modell eignet sich für erklärende sowie allgemein technische Fragestellungen.

# %%
# %%ai
# Erkläre HTTP Status Codes kurz.

# %% [markdown]
# ### GPU Status anzeigen
#
# Um zu Überprüfen ob überhaupt eine GPU verwendet wird, mittels -> `+` -> `Launcher` -> `Terminal` ein Shell Umgebung starten und folgendes Eingeben:
#
# **Nivida**
# * `watch nvidia-smi`
#
# **Intel**
# * `sudo intel_gpu_top`

# %% [markdown]
# Das zweite Beispiel verwendet das Modell `qwen2.5:7b-instruct-q4_K_M`, das sich besonders fuer strukturierte Antworten und Code-nahe Aufgaben eignet.

# %%
# %%bash
# source ~/data/env.py
# cat <<EOF | tee ~/data/env.py
# OPENAI_API_KEY="$OPENAI_API_KEY"
# HF_TOKEN=""
# AI_KUBECONFIG="$AI_KUBECONFIG"
# AI_MODEL="qwen2.5:7b-instruct-q4_K_M"
# AI_NAME=""
# AI_IP="${AI_IP}"
# AI_BASE_URL='http://localhost:11434/v1'
# EOF

# %%
# %%ai
# Schreibe ein kurzes Python Beispiel für einen REST Client.
